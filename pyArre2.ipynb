# %%
import os #os library
import pandas as pd #as dyplr library in R
import streamlit as st #library for dashboards

pd.options.display.max_columns = 999 #default cols that a df will show
pd.options.display.max_rows = 999 #default rows that a df will show
os.getcwd()
# Out:
# 'C:\\Users\\Sonia.Illanas\\Documents\\PythoniMammalia'

# %%
ORIGINAL_DATA = "H://IREC_Sonia/2_WIP/Report_202203_iMammalia/0_OriginalData/AllData_20220307_download-6225f18bc9dca3.97863955"
GBIF_DATA = "H://IREC_Sonia/2_WIP/Report_202203_iMammalia/2_WIP/"

# %%
#load your data of iMammalia and create the list of species in it
dm = pd.read_csv(
    'H://IREC_Sonia/2_WIP/Report_202203_iMammalia/0_OriginalData/AllData_20220307_download-6225f18bc9dca3.97863955/download-6225f18bc9dca3.97863955_v1.csv',
    encoding='latin-1'
)
unique_species = dm['Taxon.accepted.name'].sort_values().unique()
unique_species = [s for s in unique_species if len(s.split(' ')) == 2]
unique_species
# Out:
# ['Alces alces',
#  'Ammotragus lervia',
#  'Apodemus agrarius',
#  'Apodemus flavicollis',
#  'Apodemus sylvaticus',
#  'Arvicola sapidus',
#  'Arvicola terrestris',
#  'Atelerix algirus',
#  'Atlantoxerus getulus',
#  'Axis axis',
#  'Bison bonasus',
#  'Canis aureus',
#  'Canis lupus',
#  'Capra ibex',
#  'Capra pyrenaica',
#  'Capreolus capreolus',
#  'Castor fiber',
#  'Cervus elaphus',
#  'Cervus nippon',
#  'Clethrionomys glareolus',
#  'Cricetus cricetus',
#  'Crocidura russula',
#  'Dama dama',
#  'Eliomys quercinus',
#  'Erinaceus concolor',
#  'Erinaceus europaeus',
#  'Erinaceus roumanicus',
#  'Felis silvestris',
#  'Genetta genetta',
#  'Glis glis',
#  'Halichoerus grypus',
#  'Herpestes auropunctatus',
#  'Herpestes ichneumon',
#  'Hystrix cristata',
#  'Lepus capensis',
#  'Lepus castroviejoi',
#  'Lepus corsicanus',
#  'Lepus europaeus',
#  'Lepus granatensis',
#  'Lepus timidus',
#  'Lutra lutra',
#  'Lynx lynx',
#  'Lynx pardinus',
#  'Marmota marmota',
#  'Martes foina',
#  'Martes martes',
#  'Meles meles',
#  'Microtus arvalis',
#  'Muntiacus reevesi',
#  'Mus domesticus',
#  'Mus musculus',
#  'Muscardinus avellanarius',
#  'Mustela erminea',
#  'Mustela lutreola',
#  'Mustela nivalis',
#  'Mustela putorius',
#  'Myocastor coypus',
#  'Neovison vison',
#  'Nyctereutes procyonoides',
#  'Ondatra zibethicus',
#  'Oryctolagus cuniculus',
#  'Phoca vitulina',
#  'Procyon lotor',
#  'Rangifer tarandus',
#  'Rattus norvegicus',
#  'Rattus rattus',
#  'Rupicapra pyrenaica',
#  'Rupicapra rupicapra',
#  'Sciurus carolinensis',
#  'Sciurus meridionalis',
#  'Sciurus vulgaris',
#  'Sorex araneus',
#  'Sorex coronatus',
#  'Sorex minutus',
#  'Spermophilus citellus',
#  'Suncus etruscus',
#  'Sus scrofa',
#  'Sylvilagus floridanus',
#  'Tadarida teniotis',
#  'Talpa europaea',
#  'Talpa occidentalis',
#  'Ursus arctos',
#  'Vulpes vulpes']

# %%
import unidecode
dm['Recorded.by']=dm['Recorded.by'].str.title().str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8') #Columna Recorded.by sin acentos y en mayus
dm.to_csv('imammalia.csv', index=False) #guardar archivo de mammalnet en la ruta del sistema
# Out:
#        Unnamed: 0  ï..Record.ID     RecordKey  Sample.ID Date.interpreted  \
# 0               1      24248457  iBRC24248457   17562465       07/03/2022
# 1               2      24247884  iBRC24247884   17561936       07/03/2022
# 2               3      24247227  iBRC24247227   17561351       03/03/2022
# 3               4      24246280  iBRC24246280   17560428       07/03/2022
# 4               5      24242155  iBRC24242155   17557870       07/03/2022
# ...           ...           ...           ...        ...              ...
# 15682       15683      11889258  iBRC11889258    6847529       30/09/2017
# 15683       15684      11889226  iBRC11889226    6847527       30/09/2017
# 15684       15685      11889189  iBRC11889189    6847509       01/10/2017
# 15685       15686      11889009  iBRC11889009    6847455       13/06/2019
# 15686       15687      11879692  iBRC11879692    6842289       01/10/2019
#
#        Date.start    Date.end        Recorded.by Determined.by  \
# 0      2022-03-07  2022-03-07  Grimshaw, Stephen           NaN
# 1      2022-03-07  2022-03-07  Grimshaw, Stephen           NaN
# 2      2022-03-03  2022-03-03  Grimshaw, Stephen           NaN
# 3      2022-03-07  2022-03-07     Janner, Roland           NaN
# 4      2022-03-07  2022-03-07     Janner, Roland           NaN
# ...           ...         ...                ...           ...
# 15682  2017-09-30  2017-09-30      Smith, Graham           NaN
# 15683  2017-09-30  2017-09-30      Smith, Graham           NaN
# 15684  2017-10-01  2017-10-01      Smith, Graham           NaN
# 15685  2019-06-13  2019-06-13      Smith, Graham           NaN
# 15686  2019-10-01  2019-10-01      Smith, Graham           NaN
#
#             Grid.reference      System  Coordinate.uncertainty..m.  \
# 0               TL92699622        OSGB                          50
# 1               TL92979623        OSGB                          50
# 2               TL93349633        OSGB                          50
# 3      49.42273N 11.11575E       32632                          50
# 4      49.41207N 11.12881E       32632                          50
# ...                    ...         ...                         ...
# 15682  52.72046N 23.82763E       32634                          50
# 15683  52.71688N 23.84329E       32634                          50
# 15684  52.70294N 23.83097E       32634                          50
# 15685   40.45023N 3.58792W  UTM30WGS84                          50
# 15686           SE66725721        OSGB                          50
#
#                             Lat.Long Location.name  \
# 0       52.5297571,0.839320300000001           NaN
# 1       52.5297948,0.843535000000007           NaN
# 2       52.5306042,0.848932399999991           NaN
# 3         49.422727,11.1157472999999           NaN
# 4               49.412068,11.1288078           NaN
# ...                              ...           ...
# 15682          52.7204642,23.8276291           NaN
# 15683          52.7168769,23.8432932           NaN
# 15684          52.7029407,23.8309658           NaN
# 15685   40.4502333,-3.58791590000001           NaN
# 15686  54.0066969,-0.983383699999997           NaN
#
#                                         Higher.geography  \
# 0                                                    NaN
# 1      28; West Norfolk; 702; Vice County | NBIS; Nor...
# 2      28; West Norfolk; 702; Vice County | NBIS; Nor...
# 3      DE25; Mittelfranken; 206328; NUTS Level 2 | DE...
# 4      DE25; Mittelfranken; 206328; NUTS Level 2 | DE...
# ...                                                  ...
# 15682  PL84; Podlaskie; 206460; NUTS Level 2 | PL; Po...
# 15683  PL84; Podlaskie; 206460; NUTS Level 2 | PL; Po...
# 15684  PL84; Podlaskie; 206460; NUTS Level 2 | PL; Po...
# 15685  ES30; Comunidad de Madrid; 206298; NUTS Level ...
# 15686  62; North-east Yorkshire; 682; Vice County | N...
#
#                 Vice.County Vice.County.number Identified.by  \
# 0                       NaN                NaN           NaN
# 1              West Norfolk                 28           NaN
# 2              West Norfolk                 28           NaN
# 3                       NaN                NaN           NaN
# 4                       NaN                NaN           NaN
# ...                     ...                ...           ...
# 15682                   NaN                NaN           NaN
# 15683                   NaN                NaN           NaN
# 15684                   NaN                NaN           NaN
# 15685                   NaN                NaN           NaN
# 15686  North-east Yorkshire                 62           NaN
#
#          Taxon.accepted.name    Taxon.recorded.name Taxon.common.name  \
# 0            Lepus europaeus        Lepus europaeus        Brown hare
# 1        Capreolus capreolus    Capreolus capreolus          Roe deer
# 2          Muntiacus reevesi      Muntiacus reevesi   Reeves' muntjac
# 3           Sciurus vulgaris       Sciurus vulgaris      Red squirrel
# 4            Lepus europaeus        Lepus europaeus        Brown hare
# ...                      ...                    ...               ...
# 15682       Sciurus vulgaris       Sciurus vulgaris      Red squirrel
# 15683          Vulpes vulpes          Vulpes vulpes           Red fox
# 15684       Sciurus vulgaris       Sciurus vulgaris      Red squirrel
# 15685  Oryctolagus cuniculus  Oryctolagus cuniculus   European rabbit
# 15686  Oryctolagus cuniculus  Oryctolagus cuniculus   European rabbit
#
#               Taxon.group    Kindom    Phylum            Order     Family  \
# 0      terrestrial mammal  Animalia  Chordata       Lagomorpha  Leporidae
# 1      terrestrial mammal  Animalia  Chordata  Cetartiodactyla   Cervidae
# 2      terrestrial mammal  Animalia  Chordata  Cetartiodactyla   Cervidae
# 3      terrestrial mammal  Animalia  Chordata         Rodentia  Sciuridae
# 4      terrestrial mammal  Animalia  Chordata       Lagomorpha  Leporidae
# ...                   ...       ...       ...              ...        ...
# 15682  terrestrial mammal  Animalia  Chordata         Rodentia  Sciuridae
# 15683  terrestrial mammal  Animalia  Chordata        Carnivora    Canidae
# 15684  terrestrial mammal  Animalia  Chordata         Rodentia  Sciuridae
# 15685  terrestrial mammal  Animalia  Chordata       Lagomorpha  Leporidae
# 15686  terrestrial mammal  Animalia  Chordata       Lagomorpha  Leporidae
#
#              Genus Taxon.Version.Key Accepted.Taxon.Version.Key  Sex Stage  \
# 0            Lepus          MWEB0080                   MWEB0080  NaN   NaN
# 1        Capreolus          MWEB0026                   MWEB0026  NaN   NaN
# 2        Muntiacus           MWEB761                    MWEB761  NaN   NaN
# 3          Sciurus          MWEB0098                   MWEB0098  NaN   NaN
# 4            Lepus          MWEB0080                   MWEB0080  NaN   NaN
# ...            ...               ...                        ...  ...   ...
# 15682      Sciurus          MWEB0098                   MWEB0098  NaN   NaN
# 15683       Vulpes          MWEB0045                   MWEB0045  NaN   NaN
# 15684      Sciurus          MWEB0098                   MWEB0098  NaN   NaN
# 15685  Oryctolagus          MWEB0084                   MWEB0084  NaN   NaN
# 15686  Oryctolagus          MWEB0084                   MWEB0084  NaN   NaN
#
#       Quantity  Zero.abundance  Sensitive Record.status  Record.substatus  \
# 0            2           False      False             C               NaN
# 1            5           False      False             C               NaN
# 2            1           False      False             C               NaN
# 3            1           False      False             V               2.0
# 4            1           False      False             C               NaN
# ...        ...             ...        ...           ...               ...
# 15682        1           False      False             V               1.0
# 15683        1           False      False             V               1.0
# 15684        1           False      False             V               1.0
# 15685        1           False      False             V               1.0
# 15686        1           False      False             V               1.0
#
#       Query.status       Verifier              Verified.on           Website  \
# 0              NaN            NaN                      NaN  MammalNet-Europe
# 1              NaN            NaN                      NaN  MammalNet-Europe
# 2              NaN            NaN                      NaN  MammalNet-Europe
# 3              NaN  smith, graham  2022-03-07 11:30:54.000  MammalNet-Europe
# 4              NaN            NaN                      NaN  MammalNet-Europe
# ...            ...            ...                      ...               ...
# 15682          NaN  smith, graham  2019-11-01 09:40:15.000  MammalNet-Europe
# 15683          NaN  smith, graham  2019-10-16 15:38:42.000  MammalNet-Europe
# 15684          NaN  smith, graham  2019-11-01 09:40:15.000  MammalNet-Europe
# 15685          NaN  smith, graham  2019-11-01 09:40:15.000  MammalNet-Europe
# 15686          NaN  smith, graham  2019-10-22 11:07:08.000  MammalNet-Europe
#
#       Survey.dataset Media       long        lat
# 0      iMammalia App   NaN   0.839320  52.529757
# 1      iMammalia App   NaN   0.843535  52.529795
# 2      iMammalia App   NaN   0.848932  52.530604
# 3      iMammalia App   NaN  11.115747  49.422727
# 4      iMammalia App   NaN  11.128808  49.412068
# ...              ...   ...        ...        ...
# 15682  iMammalia App   NaN  23.827629  52.720464
# 15683  iMammalia App   NaN  23.843293  52.716877
# 15684  iMammalia App   NaN  23.830966  52.702941
# 15685  iMammalia App   NaN  -3.587916  40.450233
# 15686  iMammalia App   NaN  -0.983384  54.006697
#
# [15687 rows x 44 columns]

# %%
gbif_path=os.path.join(GBIF_DATA, 'GBIF_datasets.csv')
dg = pd.read_csv(gbif_path) #load the gbif keys 
dg
# Out:
#     Unnamed: 0                      key                 doi  \
# 0            1  0179254-210914110416597  10.15468/dl.vxhfr8
# 1            2  0179252-210914110416597  10.15468/dl.wqf95h
# 2            3  0179250-210914110416597  10.15468/dl.uxr3c8
# 3            4  0179216-210914110416597  10.15468/dl.wf3cf3
# 4            5  0179213-210914110416597  10.15468/dl.z5zsmh
# 5            6  0179210-210914110416597  10.15468/dl.r5w3sk
# 6            7  0179187-210914110416597  10.15468/dl.9xa8qn
# 7            8  0179186-210914110416597  10.15468/dl.aemk7q
# 8            9  0179185-210914110416597  10.15468/dl.a5hynr
# 9           10  0179184-210914110416597  10.15468/dl.dx8vmx
# 10          11  0179183-210914110416597  10.15468/dl.nm65f8
# 11          12  0179181-210914110416597  10.15468/dl.zxtfny
# 12          13  0179173-210914110416597  10.15468/dl.26bx54
# 13          14  0179140-210914110416597  10.15468/dl.ajg2cp
# 14          15  0179139-210914110416597  10.15468/dl.rejcqp
# 15          16  0179136-210914110416597  10.15468/dl.h3b7t4
# 16          17  0179130-210914110416597  10.15468/dl.4djxv8
# 17          18  0179121-210914110416597  10.15468/dl.xkenxn
# 18          19  0179120-210914110416597  10.15468/dl.cm6wqb
# 19          20  0179119-210914110416597  10.15468/dl.uhswyn
# 20          21  0179103-210914110416597  10.15468/dl.fyjyky
# 21          22  0179100-210914110416597  10.15468/dl.jdtx6u
# 22          23  0179091-210914110416597  10.15468/dl.8zcg3h
# 23          24  0179065-210914110416597  10.15468/dl.qpf3pn
# 24          25  0179060-210914110416597  10.15468/dl.uw8cau
# 25          26  0179055-210914110416597  10.15468/dl.f3ujh2
# 26          27  0179050-210914110416597  10.15468/dl.c42wrr
# 27          28  0179046-210914110416597  10.15468/dl.55xdrm
# 28          29  0179045-210914110416597  10.15468/dl.kcud67
# 29          30  0179041-210914110416597  10.15468/dl.myz3yw
# 30          31  0179032-210914110416597  10.15468/dl.rvyqdw
# 31          32  0179027-210914110416597  10.15468/dl.4mhhc9
# 32          33  0178998-210914110416597  10.15468/dl.whjbf5
# 33          34  0178996-210914110416597  10.15468/dl.u6y82a
# 34          35  0178994-210914110416597  10.15468/dl.2e6z25
# 35          36  0178990-210914110416597  10.15468/dl.a44hqc
# 36          37  0178965-210914110416597  10.15468/dl.p6cckf
# 37          38  0178962-210914110416597  10.15468/dl.xm66dz
# 38          39  0178958-210914110416597  10.15468/dl.kv744r
# 39          40  0178956-210914110416597  10.15468/dl.tbfxk3
# 40          41  0178955-210914110416597  10.15468/dl.xs8d4w
# 41          42  0178952-210914110416597  10.15468/dl.f45dar
# 42          43  0178933-210914110416597  10.15468/dl.uzzfrg
# 43          44  0178931-210914110416597  10.15468/dl.bcpsk6
# 44          45  0178928-210914110416597  10.15468/dl.3gssvj
# 45          46  0178907-210914110416597  10.15468/dl.msqd52
# 46          47  0178904-210914110416597  10.15468/dl.ghz9ya
# 47          48  0178902-210914110416597  10.15468/dl.jk4sxg
# 48          49  0178897-210914110416597  10.15468/dl.gaa28a
# 49          50  0178894-210914110416597  10.15468/dl.ctynjm
# 50          51  0178889-210914110416597  10.15468/dl.sumq6m
# 51          52  0178886-210914110416597  10.15468/dl.vd8fes
# 52          53  0178874-210914110416597  10.15468/dl.c3g5nv
# 53          54  0178872-210914110416597  10.15468/dl.5x8g7w
# 54          55  0178868-210914110416597  10.15468/dl.sa6a35
# 55          56  0178866-210914110416597  10.15468/dl.u7ezyk
# 56          57  0178863-210914110416597  10.15468/dl.vakdq7
# 57          58  0178834-210914110416597  10.15468/dl.x5qsem
# 58          59  0178829-210914110416597  10.15468/dl.9xhz7k
# 59          60  0178827-210914110416597  10.15468/dl.qgerp2
# 60          61  0178826-210914110416597  10.15468/dl.985bxz
# 61          62  0178824-210914110416597  10.15468/dl.232qzb
# 62          63  0178822-210914110416597  10.15468/dl.qfey6n
# 63          64  0178808-210914110416597  10.15468/dl.ezv3w7
# 64          65  0178787-210914110416597  10.15468/dl.t86759
# 65          66  0178785-210914110416597  10.15468/dl.rf8gtw
# 66          67  0178776-210914110416597  10.15468/dl.h8w6c8
# 67          68  0178753-210914110416597  10.15468/dl.y7r3hp
# 68          69  0178744-210914110416597  10.15468/dl.apbtav
# 69          70  0178739-210914110416597  10.15468/dl.j4uyev
# 70          71  0178733-210914110416597  10.15468/dl.bebrgt
# 71          72  0178729-210914110416597  10.15468/dl.xu5stf
# 72          73  0178728-210914110416597  10.15468/dl.g4qkzf
# 73          74  0178724-210914110416597  10.15468/dl.hjv2nh
# 74          75  0178721-210914110416597  10.15468/dl.sftdms
# 75          76  0178715-210914110416597  10.15468/dl.s8yy8x
# 76          77  0178711-210914110416597  10.15468/dl.939xty
# 77          78  0178709-210914110416597  10.15468/dl.zdmf6c
# 78          79  0178705-210914110416597  10.15468/dl.54672x
# 79          80  0178685-210914110416597  10.15468/dl.pnkp4s
# 80          81  0178681-210914110416597  10.15468/dl.dadhr3
# 81          82  0178680-210914110416597  10.15468/dl.2z7qx9
# 82          83  0178679-210914110416597  10.15468/dl.7zuctz
# 83          84  0178678-210914110416597  10.15468/dl.bf7wym
#
#                      species                         file
# 0              Vulpes vulpes  0179254-210914110416597.zip
# 1               Ursus arctos  0179252-210914110416597.zip
# 2         Talpa occidentalis  0179250-210914110416597.zip
# 3             Talpa europaea  0179216-210914110416597.zip
# 4          Tadarida teniotis  0179213-210914110416597.zip
# 5      Sylvilagus floridanus  0179210-210914110416597.zip
# 6                 Sus scrofa  0179187-210914110416597.zip
# 7            Suncus etruscus  0179186-210914110416597.zip
# 8      Spermophilus citellus  0179185-210914110416597.zip
# 9              Sorex minutus  0179184-210914110416597.zip
# 10           Sorex coronatus  0179183-210914110416597.zip
# 11             Sorex araneus  0179181-210914110416597.zip
# 12          Sciurus vulgaris  0179173-210914110416597.zip
# 13      Sciurus carolinensis  0179140-210914110416597.zip
# 14       Rupicapra rupicapra  0179139-210914110416597.zip
# 15       Rupicapra pyrenaica  0179136-210914110416597.zip
# 16             Rattus rattus  0179130-210914110416597.zip
# 17         Rattus norvegicus  0179121-210914110416597.zip
# 18         Rangifer tarandus  0179120-210914110416597.zip
# 19             Procyon lotor  0179119-210914110416597.zip
# 20            Phoca vitulina  0179103-210914110416597.zip
# 21                Ovis aries  0179100-210914110416597.zip
# 22     Oryctolagus cuniculus  0179091-210914110416597.zip
# 23        Ondatra zibethicus  0179065-210914110416597.zip
# 24  Nyctereutes procyonoides  0179060-210914110416597.zip
# 25            Neovison vison  0179055-210914110416597.zip
# 26          Myocastor coypus  0179050-210914110416597.zip
# 27          Mustela putorius  0179046-210914110416597.zip
# 28           Mustela nivalis  0179045-210914110416597.zip
# 29          Mustela lutreola  0179041-210914110416597.zip
# 30           Mustela erminea  0179032-210914110416597.zip
# 31  Muscardinus avellanarius  0179027-210914110416597.zip
# 32              Mus musculus  0178998-210914110416597.zip
# 33              Mus musculus  0178996-210914110416597.zip
# 34         Muntiacus reevesi  0178994-210914110416597.zip
# 35          Microtus arvalis  0178990-210914110416597.zip
# 36               Meles meles  0178965-210914110416597.zip
# 37             Martes martes  0178962-210914110416597.zip
# 38              Martes foina  0178958-210914110416597.zip
# 39           Marmota marmota  0178956-210914110416597.zip
# 40             Lynx pardinus  0178955-210914110416597.zip
# 41                 Lynx lynx  0178952-210914110416597.zip
# 42               Lutra lutra  0178933-210914110416597.zip
# 43             Lepus timidus  0178931-210914110416597.zip
# 44         Lepus granatensis  0178928-210914110416597.zip
# 45           Lepus europaeus  0178907-210914110416597.zip
# 46          Lepus corsicanus  0178904-210914110416597.zip
# 47        Lepus castroviejoi  0178902-210914110416597.zip
# 48            Lepus capensis  0178897-210914110416597.zip
# 49          Hystrix cristata  0178894-210914110416597.zip
# 50       Herpestes ichneumon  0178889-210914110416597.zip
# 51       Herpestes javanicus  0178886-210914110416597.zip
# 52        Halichoerus grypus  0178874-210914110416597.zip
# 53                 Glis glis  0178872-210914110416597.zip
# 54           Genetta genetta  0178868-210914110416597.zip
# 55          Felis silvestris  0178866-210914110416597.zip
# 56      Erinaceus roumanicus  0178863-210914110416597.zip
# 57       Erinaceus europaeus  0178834-210914110416597.zip
# 58        Erinaceus concolor  0178829-210914110416597.zip
# 59         Eliomys quercinus  0178827-210914110416597.zip
# 60                 Dama dama  0178826-210914110416597.zip
# 61         Crocidura russula  0178824-210914110416597.zip
# 62         Cricetus cricetus  0178822-210914110416597.zip
# 63          Myodes glareolus  0178808-210914110416597.zip
# 64          Myodes glareolus  0178787-210914110416597.zip
# 65             Cervus nippon  0178785-210914110416597.zip
# 66            Cervus elaphus  0178776-210914110416597.zip
# 67              Castor fiber  0178753-210914110416597.zip
# 68       Capreolus capreolus  0178744-210914110416597.zip
# 69           Capra pyrenaica  0178739-210914110416597.zip
# 70                Capra ibex  0178733-210914110416597.zip
# 71               Canis lupus  0178729-210914110416597.zip
# 72              Canis aureus  0178728-210914110416597.zip
# 73             Bison bonasus  0178724-210914110416597.zip
# 74                 Axis axis  0178721-210914110416597.zip
# 75      Atlantoxerus getulus  0178715-210914110416597.zip
# 76          Atelerix algirus  0178711-210914110416597.zip
# 77        Arvicola amphibius  0178709-210914110416597.zip
# 78          Arvicola sapidus  0178705-210914110416597.zip
# 79       Apodemus sylvaticus  0178685-210914110416597.zip
# 80      Apodemus flavicollis  0178681-210914110416597.zip
# 81         Apodemus agrarius  0178680-210914110416597.zip
# 82         Ammotragus lervia  0178679-210914110416597.zip
# 83               Alces alces  0178678-210914110416597.zip

# %%
fox = dg.loc[0]
fox
# Out:
# Unnamed: 0                              1
# key               0179254-210914110416597
# doi                    10.15468/dl.vxhfr8
# species                     Vulpes vulpes
# file          0179254-210914110416597.zip
# Name: 0, dtype: object

# %%
from zipfile import ZipFile #library for importing .zip files
#ZipFile().extract()
species=unique_species

# %%
fox_file = os.path.join(GBIF_DATA, fox['file'])
fox_key_file = os.path.join('dataset', fox['key'], '.xml')
ZipFile(fox_file).extract('occurrence.txt')
fox_key_file
fox_files = [f.filename for f in ZipFile(fox_file).filelist]
fox_xml = ZipFile(fox_file).extract(fox_files[0])
fox_xml

# %%
def write_occurrences(species):
    print(species)
    cols_to_keep = ['species', 'speciesKey', 'scientificName', 'scientificNameID', 'year',
                    'decimalLatitude', 'decimalLongitude', 'coordinatePrecision','coordinateUncertaintyInMeters',
                    'iucnRedListCategory']
    cols_to_rename = {
        'decimalLatitude': 'lat',
        'decimalLongitude': 'lon',
    }

    try:
        species_row = dg.loc[dg['spGBIF'] == species].iloc[0]
    except IndexError:
        print(f'ERROR: {species} no está descargado del GBIF')
        return None

    full_species_file = os.path.join(GBIF_DATA, species_row['file'])
    
    txt_path = ZipFile(full_species_file).extract('occurrence.txt', full_species_file.replace('.zip', ''))
    occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
    occ_df = occ_df.rename(columns=cols_to_rename)
    
    occ_df = occ_df.loc[occ_df['coordinatePrecision'] <= 2000]
    
    species_prefix = species.lower().replace(' ', '_')
    # save_name = f'{species_prefix}_{species_row.key}_{species_row.doi}.csv'
    save_name = f'{species_prefix}_{species_row

.key}.csv'

    occ_df.to_csv(os.path.join('species', save_name), index=False)
# Out:
#   File "<ipython-input-37-c7c406991d64>", line 27
#     save_name = f'{species_prefix}_{species_row
#                                                ^
# SyntaxError: EOL while scanning string literal

# %%
from tqdm.auto import tqdm

# %%
for sp in tqdm(unique_species):
    write_occurrences(sp)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=83.0), HTML(value='')))
# Alces alces
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Ammotragus lervia
# Apodemus agrarius
# Apodemus flavicollis
# Apodemus sylvaticus
# Arvicola sapidus
# Arvicola terrestris
# ERROR: Arvicola terrestris no está descargado del GBIF
# Atelerix algirus
# Atlantoxerus getulus
# Axis axis
# Bison bonasus
# Canis aureus
# Canis lupus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Capra ibex
# Capra pyrenaica
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (256) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Capreolus capreolus
# Castor fiber
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Cervus elaphus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Cervus nippon
# Clethrionomys glareolus
# ERROR: Clethrionomys glareolus no está descargado del GBIF
# Cricetus cricetus
# Crocidura russula
# Dama dama
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Eliomys quercinus
# Erinaceus concolor
# Erinaceus europaeus
# Erinaceus roumanicus
# Felis silvestris
# Genetta genetta
# Glis glis
# Halichoerus grypus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Herpestes auropunctatus
# ERROR: Herpestes auropunctatus no está descargado del GBIF
# Herpestes ichneumon
# Hystrix cristata
# Lepus capensis
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Lepus castroviejoi
# Lepus corsicanus
# Lepus europaeus
# Lepus granatensis
# Lepus timidus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (256) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Lutra lutra
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Lynx lynx
# Lynx pardinus
# Marmota marmota
# Martes foina
# Martes martes
# Meles meles
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Microtus arvalis
# Muntiacus reevesi
# Mus domesticus
# ERROR: Mus domesticus no está descargado del GBIF
# Mus musculus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Muscardinus avellanarius
# Mustela erminea
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Mustela lutreola
# Mustela nivalis
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Mustela putorius
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Myocastor coypus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Neovison vison
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Nyctereutes procyonoides
# Ondatra zibethicus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Oryctolagus cuniculus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Phoca vitulina
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Procyon lotor
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Rangifer tarandus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Rattus norvegicus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Rattus rattus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Rupicapra pyrenaica
# Rupicapra rupicapra
# Sciurus carolinensis
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Sciurus meridionalis
# ERROR: Sciurus meridionalis no está descargado del GBIF
# Sciurus vulgaris
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Sorex araneus
# Sorex coronatus
# Sorex minutus
# Spermophilus citellus
# Suncus etruscus
# Sus scrofa
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Sylvilagus floridanus
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Tadarida teniotis
# Talpa europaea
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (238) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')
# Talpa occidentalis
# Ursus arctos
# Vulpes vulpes
# <ipython-input-123-00115330bf09>:20: DtypeWarning: Columns (181,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')

# %%
alces = pd.read_csv('C://Users/Sonia.Illanas/Documents/PythoniMammalia/species/alces_alces_0184134-210914110416597.csv', encoding='latin1')
alces
# Out:
# <ipython-input-6-4c3914a7374a>:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   alces = pd.read_csv('C://Users/Sonia.Illanas/Documents/PythoniMammalia/species/alces_alces_0184134-210914110416597.csv', encoding='latin1')
#        year        lat        lon  coordinateUncertaintyInMeters  \
# 0      2022  62.390768  23.337986                            1.0
# 1      1966  61.331825  28.660437                         1000.0
# 2      2022  62.395936  23.317877                            1.0
# 3      2022  63.720160   9.741996                          100.0
# 4      2022  68.464338  16.699852                           25.0
# ...     ...        ...        ...                            ...
# 86785  1928  57.746200  15.127000                            NaN
# 86786  1925  57.791600  13.121500                            NaN
# 86787  1919  65.584440  22.153890                            NaN
# 86788  1919  57.054720  15.788610                            NaN
# 86789  1989   0.000000   0.000000                            NaN
#
#        coordinatePrecision scientificNameID                scientificName  \
# 0                      NaN              NaN  Alces alces (Linnaeus, 1758)
# 1                      NaN              NaN  Alces alces (Linnaeus, 1758)
# 2                      NaN              NaN  Alces alces (Linnaeus, 1758)
# 3                      NaN              NaN  Alces alces (Linnaeus, 1758)
# 4                      NaN              NaN  Alces alces (Linnaeus, 1758)
# ...                    ...              ...                           ...
# 86785                  NaN              NaN  Alces alces (Linnaeus, 1758)
# 86786                  NaN              NaN  Alces alces (Linnaeus, 1758)
# 86787                  NaN              NaN  Alces alces (Linnaeus, 1758)
# 86788                 0.01              NaN  Alces alces (Linnaeus, 1758)
# 86789                  NaN              NaN  Alces alces (Linnaeus, 1758)
#
#        speciesKey      species iucnRedListCategory
# 0         2440940  Alces alces                  LC
# 1         2440940  Alces alces                  LC
# 2         2440940  Alces alces                  LC
# 3         2440940  Alces alces                  LC
# 4         2440940  Alces alces                  LC
# ...           ...          ...                 ...
# 86785     2440940  Alces alces                  LC
# 86786     2440940  Alces alces                  LC
# 86787     2440940  Alces alces                  LC
# 86788     2440940  Alces alces                  LC
# 86789     2440940  Alces alces                  LC
#
# [86790 rows x 10 columns]

# %%
occurences.head(2)
# Out:
#        gbifID  abstract accessRights  accrualMethod  accrualPeriodicity  \
# 0  3699001319       NaN          NaN            NaN                 NaN
# 1  3699001318       NaN          NaN            NaN                 NaN
#
#    accrualPolicy  alternative  audience  available bibliographicCitation  \
# 0            NaN          NaN       NaN        NaN                   NaN
# 1            NaN          NaN       NaN        NaN                   NaN
#
#    conformsTo  contributor  coverage  created  creator  date  dateAccepted  \
# 0         NaN          NaN       NaN      NaN      NaN   NaN           NaN
# 1         NaN          NaN       NaN      NaN      NaN   NaN           NaN
#
#    dateCopyrighted  dateSubmitted  description  educationLevel  extent  \
# 0              NaN            NaN          NaN             NaN     NaN
# 1              NaN            NaN          NaN             NaN     NaN
#
#    format  hasFormat  hasPart  hasVersion identifier  instructionalMethod  \
# 0     NaN        NaN      NaN         NaN     709831                  NaN
# 1     NaN        NaN      NaN         NaN     709787                  NaN
#
#    isFormatOf  isPartOf  isReferencedBy  isReplacedBy  isRequiredBy  \
# 0         NaN       NaN             NaN           NaN           NaN
# 1         NaN       NaN             NaN           NaN           NaN
#
#    isVersionOf  issued language    license  mediator  medium  \
# 0          NaN     NaN      NaN  CC_BY_4_0       NaN     NaN
# 1          NaN     NaN      NaN  CC_BY_4_0       NaN     NaN
#
#                modified  provenance  publisher references  relation  replaces  \
# 0  2022-02-16T00:00:00Z         NaN        NaN        NaN       NaN       NaN
# 1  2022-02-14T00:00:00Z         NaN        NaN        NaN       NaN       NaN
#
#    requires  rights rightsHolder  source  spatial  subject  tableOfContents  \
# 0       NaN     NaN          NaN     NaN      NaN      NaN              NaN
# 1       NaN     NaN          NaN     NaN      NaN      NaN              NaN
#
#    temporal  title type  valid institutionID collectionID datasetID  \
# 0       NaN    NaN  NaN    NaN           NaN          NaN       NaN
# 1       NaN    NaN  NaN    NaN           NaN          NaN       NaN
#
#   institutionCode collectionCode datasetName ownerInstitutionCode  \
# 0        BioFokus       BioFokus         NaN                  NaN
# 1        BioFokus       BioFokus         NaN                  NaN
#
#        basisOfRecord informationWithheld dataGeneralizations  \
# 0  HUMAN_OBSERVATION                 NaN                 NaN
# 1  HUMAN_OBSERVATION                 NaN                 NaN
#
#   dynamicProperties occurrenceID catalogNumber recordNumber   recordedBy  \
# 0               NaN       709831        709831          NaN  Olsen, K.M.
# 1               NaN       709787        709787          NaN  Olsen, K.M.
#
#   recordedByID  individualCount  organismQuantity organismQuantityType  \
# 0          NaN              1.0               NaN                  NaN
# 1          NaN              1.0               NaN                  NaN
#
#       sex lifeStage reproductiveCondition behavior establishmentMeans  \
# 0  FEMALE       NaN                   NaN      NaN                NaN
# 1  FEMALE       NaN                   NaN      NaN                NaN
#
#    degreeOfEstablishment  pathway georeferenceVerificationStatus  \
# 0                    NaN      NaN                            NaN
# 1                    NaN      NaN                            NaN
#
#   occurrenceStatus preparations disposition associatedOccurrences  \
# 0          PRESENT          NaN         NaN                   NaN
# 1          PRESENT          NaN         NaN                   NaN
#
#   associatedReferences associatedSequences associatedTaxa otherCatalogNumbers  \
# 0                  NaN                 NaN            NaN                 NaN
# 1                  NaN                 NaN            NaN                 NaN
#
#   occurrenceRemarks organismID  organismName  organismScope  \
# 0               NaN        NaN           NaN            NaN
# 1               NaN        NaN           NaN            NaN
#
#    associatedOrganisms previousIdentifications  organismRemarks  \
# 0                  NaN                     NaN              NaN
# 1                  NaN                     NaN              NaN
#
#    materialSampleID eventID parentEventID fieldNumber            eventDate  \
# 0               NaN     NaN           NaN    709831.0  2017-07-07T00:00:00
# 1               NaN     NaN           NaN    709787.0  2017-06-28T00:00:00
#
#   eventTime  startDayOfYear  endDayOfYear  year  month   day  \
# 0       NaN             NaN           NaN  2017    7.0   7.0
# 1       NaN             NaN           NaN  2017    6.0  28.0
#
#   verbatimEventDate habitat samplingProtocol  sampleSizeValue sampleSizeUnit  \
# 0               NaN     NaN              NaN              NaN            NaN
# 1               NaN     NaN              NaN              NaN            NaN
#
#    samplingEffort fieldNotes eventRemarks locationID  higherGeographyID  \
# 0             NaN        NaN          NaN        NaN                NaN
# 1             NaN        NaN          NaN        NaN                NaN
#
#   higherGeography continent waterBody islandGroup island countryCode  \
# 0             NaN    EUROPE       NaN         NaN    NaN          NO
# 1             NaN    EUROPE       NaN         NaN    NaN          NO
#
#   stateProvince county municipality  \
# 0         Troms  Bardu          NaN
# 1       Oppland  Dovre          NaN
#
#                                     locality verbatimLocality  \
# 0            Bjørkeng – Langs Altevannsveien              NaN
# 1  S Toftemo – Langs Gudbrandsdalsvegen (E6)              NaN
#
#    verbatimElevation  verticalDatum  verbatimDepth  \
# 0                NaN            NaN            NaN
# 1                NaN            NaN            NaN
#
#    minimumDistanceAboveSurfaceInMeters  maximumDistanceAboveSurfaceInMeters  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
#
#   locationAccordingTo locationRemarks  decimalLatitude  decimalLongitude  \
# 0                 NaN             NaN        68.754723         18.526702
# 1                 NaN             NaN        61.994396          9.229161
#
#    coordinateUncertaintyInMeters  coordinatePrecision  pointRadiusSpatialFit  \
# 0                            NaN                  NaN                    NaN
# 1                            NaN                  NaN                    NaN
#
#   verbatimCoordinateSystem verbatimSRS footprintWKT footprintSRS  \
# 0                      NaN         NaN          NaN          NaN
# 1                      NaN         NaN          NaN          NaN
#
#    footprintSpatialFit georeferencedBy georeferencedDate georeferenceProtocol  \
# 0                  NaN             NaN               NaN                  NaN
# 1                  NaN             NaN               NaN                  NaN
#
#   georeferenceSources georeferenceRemarks  geologicalContextID  \
# 0                 NaN                 NaN                  NaN
# 1                 NaN                 NaN                  NaN
#
#   earliestEonOrLowestEonothem latestEonOrHighestEonothem  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
#
#   earliestEraOrLowestErathem latestEraOrHighestErathem  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
#
#   earliestPeriodOrLowestSystem latestPeriodOrHighestSystem  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#   earliestEpochOrLowestSeries latestEpochOrHighestSeries  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
#
#    earliestAgeOrLowestStage  latestAgeOrHighestStage  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
#
#    lowestBiostratigraphicZone  highestBiostratigraphicZone  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
#
#   lithostratigraphicTerms  group  formation  member  bed  identificationID  \
# 0                     NaN    NaN        NaN     NaN  NaN               NaN
# 1                     NaN    NaN        NaN     NaN  NaN               NaN
#
#   verbatimIdentification identificationQualifier typeStatus identifiedBy  \
# 0                    NaN                     NaN        NaN  Olsen, K.M.
# 1                    NaN                     NaN        NaN  Olsen, K.M.
#
#   identifiedByID       dateIdentified identificationReferences  \
# 0            NaN  2017-07-07T00:00:00                      NaN
# 1            NaN  2017-06-28T00:00:00                      NaN
#
#   identificationVerificationStatus identificationRemarks taxonID  \
# 0                              NaN                   NaN     NaN
# 1                              NaN                   NaN     NaN
#
#   scientificNameID acceptedNameUsageID parentNameUsageID  originalNameUsageID  \
# 0              NaN                 NaN               NaN                  NaN
# 1              NaN                 NaN               NaN                  NaN
#
#    nameAccordingToID  namePublishedInID taxonConceptID  \
# 0                NaN                NaN            NaN
# 1                NaN                NaN            NaN
#
#                  scientificName acceptedNameUsage parentNameUsage  \
# 0  Alces alces (Linnaeus, 1758)               NaN             NaN
# 1  Alces alces (Linnaeus, 1758)               NaN             NaN
#
#    originalNameUsage  nameAccordingTo  namePublishedIn  namePublishedInYear  \
# 0                NaN              NaN              NaN                  NaN
# 1                NaN              NaN              NaN                  NaN
#
#   higherClassification   kingdom    phylum     class         order    family  \
# 0                  NaN  Animalia  Chordata  Mammalia  Artiodactyla  Cervidae
# 1                  NaN  Animalia  Chordata  Mammalia  Artiodactyla  Cervidae
#
#    subfamily  genus genericName  subgenus  infragenericEpithet  \
# 0        NaN  Alces       Alces       NaN                  NaN
# 1        NaN  Alces       Alces       NaN                  NaN
#
#   specificEpithet infraspecificEpithet  cultivarEpithet taxonRank  \
# 0           alces                  NaN              NaN   SPECIES
# 1           alces                  NaN              NaN   SPECIES
#
#    verbatimTaxonRank vernacularName nomenclaturalCode taxonomicStatus  \
# 0                NaN            NaN               NaN        ACCEPTED
# 1                NaN            NaN               NaN        ACCEPTED
#
#   nomenclaturalStatus taxonRemarks                            datasetKey  \
# 0                 NaN          NaN  2e4cc37b-302e-4f1b-bbbb-1f674ff90e14
# 1                 NaN          NaN  2e4cc37b-302e-4f1b-bbbb-1f674ff90e14
#
#   publishingCountry           lastInterpreted  elevation  elevationAccuracy  \
# 0                NO  2022-03-10T09:41:12.784Z       80.0                NaN
# 1                NO  2022-03-10T09:41:12.775Z      465.0                NaN
#
#    depth  depthAccuracy  distanceAboveSurface  distanceAboveSurfaceAccuracy  \
# 0    NaN            NaN                   NaN                           NaN
# 1    NaN            NaN                   NaN                           NaN
#
#                                                issue mediaType  hasCoordinate  \
# 0  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_PRECIS...       NaN           True
# 1  GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_PRECIS...       NaN           True
#
#    hasGeospatialIssues  taxonKey  acceptedTaxonKey  kingdomKey  phylumKey  \
# 0                False   2440940           2440940           1         44
# 1                False   2440940           2440940           1         44
#
#    classKey  orderKey  familyKey  genusKey  subgenusKey  speciesKey  \
# 0       359       731       5298   7816758          NaN     2440940
# 1       359       731       5298   7816758          NaN     2440940
#
#        species        acceptedScientificName verbatimScientificName  \
# 0  Alces alces  Alces alces (Linnaeus, 1758)            Alces alces
# 1  Alces alces  Alces alces (Linnaeus, 1758)            Alces alces
#
#    typifiedName     protocol                lastParsed  \
# 0           NaN  DWC_ARCHIVE  2022-03-10T09:41:12.784Z
# 1           NaN  DWC_ARCHIVE  2022-03-10T09:41:12.775Z
#
#                 lastCrawled repatriated  relativeOrganismQuantity level0Gid  \
# 0  2022-03-10T09:33:34.097Z       False                       NaN       NOR
# 1  2022-03-10T09:33:34.097Z       False                       NaN       NOR
#
#   level0Name level1Gid level1Name   level2Gid level2Name level3Gid level3Name  \
# 0     Norway  NOR.17_1      Troms  NOR.17.2_1      Bardu       NaN        NaN
# 1     Norway  NOR.11_1    Oppland  NOR.11.1_1      Dovre       NaN        NaN
#
#   iucnRedListCategory
# 0                  LC
# 1                  LC

# %%
occurences[['species', 'speciesKey']]
# Out:
#            species  speciesKey
# 0      Alces alces     2440940
# 1      Alces alces     2440940
# 2      Alces alces     2440940
# 3      Alces alces     2440940
# 4      Alces alces     2440940
# ...            ...         ...
# 86740  Alces alces     2440940
# 86741  Alces alces     2440940
# 86742  Alces alces     2440940
# 86743  Alces alces     2440940
# 86744  Alces alces     2440940
#
# [86745 rows x 2 columns]

# %%
occurences = pd.read_csv('occurrence.txt', sep='\t')
# Out:
# <ipython-input-59-5e13066939bc>:1: DtypeWarning: Columns (2,9,26,35,39,42,47,54,56,57,58,61,62,64,65,66,67,68,69,71,74,75,76,77,78,79,82,84,85,86,87,88,89,90,91,92,96,99,100,101,103,109,110,111,113,115,116,117,119,120,121,122,123,125,126,128,129,135,136,142,143,144,145,147,148,149,150,151,153,154,155,156,157,158,159,160,165,171,172,173,174,175,176,177,178,179,180,181,182,183,187,189,190,195,207,211,212,214,215,226,246,254,255) have mixed types. Specify dtype option on import or set low_memory=False.
#   occurences = pd.read_csv('occurrence.txt', sep='\t')

# %%
occurences.shape
# Out:
# (86745, 257)

# %% [markdown]
# ###### fox_file = os.path.join(GBIF_DATA, fox['file'])
# fox_key_file = os.path.join('dataset', fox['key'], '.xml')

# %%
get_occurrences('Sus scrofa')
# Out:
# Sus scrofa
# <ipython-input-110-465fc8c06a7d>:20: DtypeWarning: Columns (181) have mixed types. Specify dtype option on import or set low_memory=False.
#   occ_df = pd.read_csv(txt_path, usecols=cols_to_keep, sep='\t')

# %%
import pydeck as pdk
dm = dm.loc[(dm['Record.status'] == 'V')]
unique_species = dm['Taxon.accepted.name'].sort_values().unique()
dm = dm.rename(columns={'long': 'lon'})
unique_species = dm['Taxon.accepted.name'].sort_values().unique()
unique_species = [s for s in unique_species if len(s.split(' ')) == 2]
specie='Canis lupus'
dm_specie = dm.loc[dm['Taxon.accepted.name'] == specie]
dm_specie = dm_specie.dropna(subset=['lon', 'lat'])
dm_specie=dm_specie[['lon', 'lat', 'Recorded.by', 'Date.end']]
pdk.Deck(
     map_style='mapbox://styles/mapbox/light-v9',
     initial_view_state=pdk.ViewState(
         latitude=56.5,
         longitude=9.5,
         zoom=2.25
     ),
     layers=[
         pdk.Layer(
            'ScatterplotLayer',
            data=dm_specie,
            pickable=True,
            opacity=0.2,
            stroked=True,
            filled=True,
            radius_scale=5,
            radius_min_pixels=5,
            radius_max_pixels=100,
            line_width_min_pixels=1,
            get_line_color=[0, 0, 0],
            get_fill_color=[235, 235, 66],
            get_position='[lon, lat]'
         )
     ],
    tooltip={"html": "<b>Date: </b> {Date.end} <br /> "
                  "<b>Recorded by: </b> {Recorded.by} <br /> "}
 )
# Out:
# {"initialViewState": {"latitude": 56.5, "longitude": 9.5, "zoom": 2.25}, "layers": [{"@@type": "ScatterplotLayer", "data": [{"Date.end": "2022-02-10", "Recorded.by": "Jaszczuk, Iza", "lat": 54.6524035, "lon": 17.9206776}, {"Date.end": "2022-01-12", "Recorded.by": "Miletic, Aleksandar", "lat": 44.1089846, "lon": 21.4057829}, {"Date.end": "2021-12-16", "Recorded.by": "Deretic, Stanko", "lat": 42.6286251, "lon": 18.6548406}, {"Date.end": "2021-11-19", "Recorded.by": "Miletic, Aleksandar", "lat": 43.3845129, "lon": 22.5360918}, {"Date.end": "2021-11-17", "Recorded.by": "Grabowski, Andrzej", "lat": 54.0850138, "lon": 20.9087554}, {"Date.end": "2021-11-06", "Recorded.by": "Antonacci, Domenico Sergio", "lat": 41.7023451, "lon": 15.7324654}, {"Date.end": "2020-09-19", "Recorded.by": "Nagy, Eszter", "lat": 43.3271773, "lon": 17.0285554}, {"Date.end": "2020-08-29", "Recorded.by": "Nagy, Eszter", "lat": 43.3261842, "lon": 17.0275132}, {"Date.end": "2020-08-29", "Recorded.by": "Nagy, Eszter", "lat": 43.3261676, "lon": 17.0274994}, {"Date.end": "2020-09-06", "Recorded.by": "Nagy, Eszter", "lat": 43.331729, "lon": 17.0339584}, {"Date.end": "2021-10-18", "Recorded.by": "Miersch, Christian", "lat": 51.2748202, "lon": 14.9383363}, {"Date.end": "2021-09-27", "Recorded.by": "Nagy, Eszter", "lat": 45.2027942, "lon": 16.1073209}, {"Date.end": "2021-09-05", "Recorded.by": "Nagy, Eszter", "lat": 45.2027935, "lon": 16.1073129}, {"Date.end": "2021-09-27", "Recorded.by": "Nagy, Eszter", "lat": 45.2043145, "lon": 16.1100313}, {"Date.end": "2021-09-13", "Recorded.by": "Nagy, Eszter", "lat": 45.2043296, "lon": 16.1100179}, {"Date.end": "2021-09-05", "Recorded.by": "Nagy, Eszter", "lat": 45.2043122, "lon": 16.1100083}, {"Date.end": "2021-09-27", "Recorded.by": "Nagy, Eszter", "lat": 45.2046241, "lon": 16.1124756}, {"Date.end": "2021-10-03", "Recorded.by": "Nagy, Eszter", "lat": 45.2032138, "lon": 16.1145414}, {"Date.end": "2021-09-18", "Recorded.by": "Nagy, Eszter", "lat": 45.2007099, "lon": 16.1155592}, {"Date.end": "2021-10-03", "Recorded.by": "Nagy, Eszter", "lat": 45.2030918, "lon": 16.1178312}, {"Date.end": "2021-09-04", "Recorded.by": "Nagy, Eszter", "lat": 45.2030398, "lon": 16.1178952}, {"Date.end": "2021-09-12", "Recorded.by": "Nagy, Eszter", "lat": 45.2106189, "lon": 16.1016973}, {"Date.end": "2021-09-30", "Recorded.by": "Nagy, Eszter", "lat": 45.2124988, "lon": 16.0970038}, {"Date.end": "2021-09-17", "Recorded.by": "Nagy, Eszter", "lat": 45.2125062, "lon": 16.0969954}, {"Date.end": "2021-09-05", "Recorded.by": "Nagy, Eszter", "lat": 45.2124938, "lon": 16.0970023000001}, {"Date.end": "2021-09-20", "Recorded.by": "Kadiu, Kliton", "lat": 40.2337252, "lon": 19.5955563}, {"Date.end": "2021-09-12", "Recorded.by": "Nagy, Eszter", "lat": 45.2141859, "lon": 16.0987741}, {"Date.end": "2021-10-04", "Recorded.by": "Nagy, Eszter", "lat": 45.2160964, "lon": 16.097433}, {"Date.end": "2021-09-29", "Recorded.by": "Nagy, Eszter", "lat": 45.2160964, "lon": 16.0974196}, {"Date.end": "2021-09-21", "Recorded.by": "Nagy, Eszter", "lat": 45.216064, "lon": 16.0973954}, {"Date.end": "2021-09-04", "Recorded.by": "Nagy, Eszter", "lat": 45.2160136, "lon": 16.0974268}, {"Date.end": "2021-10-07", "Recorded.by": "Guerrasio, Tancredi", "lat": 43.7091188, "lon": 11.0573638}, {"Date.end": "2021-09-06", "Recorded.by": "Nagy, Eszter", "lat": 45.1972744, "lon": 16.1014107}, {"Date.end": "2021-09-05", "Recorded.by": "Nagy, Eszter", "lat": 45.1972739, "lon": 16.1014071}, {"Date.end": "2021-10-04", "Recorded.by": "Nagy, Eszter", "lat": 45.1971743, "lon": 16.1043558}, {"Date.end": "2021-09-18", "Recorded.by": "Nagy, Eszter", "lat": 45.1972102, "lon": 16.1043665}, {"Date.end": "2021-09-05", "Recorded.by": "Nagy, Eszter", "lat": 45.1971887, "lon": 16.1043126}, {"Date.end": "2021-09-05", "Recorded.by": "Nagy, Eszter", "lat": 45.1967769, "lon": 16.1070341}, {"Date.end": "2021-10-04", "Recorded.by": "Nagy, Eszter", "lat": 45.1988328, "lon": 16.1048375}, {"Date.end": "2021-10-03", "Recorded.b ...
